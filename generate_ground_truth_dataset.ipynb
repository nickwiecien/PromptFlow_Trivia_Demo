# %%
import pandas as pd

df = pd.read_csv('formatted_trivia_questions.csv')

df = df[['Question', 'Answer', 'BackgroundContent']]

sample = df.sample(1000)

sample
# Out:
#                                                Question           Answer  \
# 4429  The 2012 best selling book 'My Animals and Oth...    CLARE BALDING
# 5122  Known as The Hoosier State, what was the 19th ...          Indiana
# 8827  The Wasp Factory was the debut novel of which ...       Iain Banks
# 3488  Who is the father-in-law of Manchester City fo...   DIEGO MARADONA
# 5444  In 1995 who famously walked out of the play 'C...      STEPHEN FRY
# ...                                                 ...              ...
# 5671  The world's deepest known cave is in which cou...          Georgia
# 7847  The painters Theodore Rousseau and Jean-Franco...  BARBIZON SCHOOL
# 5771  The 2013 G8 Summit was held at Lough Erne Reso...        FERMANAGH
# 4626  In which country was England Rugby Union playe...      NEW ZEALAND
# 1838  Which wife of Henry VIII had already married t...   Catherine Parr
#
#                                       BackgroundContent
# ...

# %%
sample.to_json('triva_ground_truth.jsonl', orient='records', lines=True)
